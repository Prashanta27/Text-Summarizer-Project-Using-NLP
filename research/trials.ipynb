# %%
from box import ConfigBox

# %%
d = ConfigBox({"key":"value","key":"value"})

# %%
d.key
# Out:
# 'value'

# %%
def get_product(x: int, y: int) -> int:
    return x * y

# %%
get_product(x = 2, y = 4)
# Out:
# 8

# %%
get_product(x =2, y = "4")
# Out:
# '44'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x: int, y: int) -> int:
    return x * y

# %%
get_product(x = 2, y = 4)
# Out:
# 8

# %%
#get_product(x =2, y = "4")
